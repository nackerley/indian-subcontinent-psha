# %%
import pandas as pd

# %%
gmpe_summary_csv = 'NT2012_GMPEs.csv'
df_gmpes = pd.read_csv(gmpe_summary_csv)
df_gmpes
# Out:
#                    OpenQuake class   New to OQ    Obsolete  \
# 0                  AkkarBommer2010         NaN  \checkmark
# 1                BooreAtkinson2008         NaN  \checkmark
# 2            CampbellBozorgnia2008         NaN  \checkmark
# 3                 Kanno2006Shallow  \checkmark         NaN
# 4                   SharmaEtAl2009  \checkmark         NaN
# 5                NathEtAl2012Upper  \checkmark         NaN
# 6                NathEtAl2012Lower  \checkmark         NaN
# 7                AtkinsonBoore2006         NaN         NaN
# 8                     Campbell2003         NaN         NaN
# 9            RaghukanthIyengar2007  \checkmark         NaN
# 10                    ToroEtAl2002         NaN         NaN
# 11                   Kanno2006Deep  \checkmark         NaN
# 12         AtkinsonBoore2003SInter         NaN         NaN
# 13              AtkinsonMacias2009         NaN         NaN
# 14     AtkinsonBoore2003SSlabJapan  \checkmark         NaN
# 15  AtkinsonBoore2003SSlabCascadia  \checkmark         NaN
# 16                 LinLee2008SSlab         NaN         NaN
# 17                  Gupta2010SSlab  \checkmark         NaN
# 18             YoungsEtAl1997SSlab         NaN         NaN
# 19               ZhaoEtAl2006SSlab         NaN  \checkmark
#
#                  Database       Tectonic Region                NE     NR  \
# 0    Europe & Middle East  active shallow crust               131    532
# 1                NGA-West  active shallow crust                58   1574
# 2                NGA-West  active shallow crust                72    942
# 3                   Japan  active shallow crust                83   3769
# 4      Himalayas & Zagros  active shallow crust                16    201
# 5        India (Shillong)     intraplate margin        simulation    NaN
# 6        India (Shillong)     intraplate margin        simulation    NaN
# 7   Eastern North America  stable shallow crust                10  34800
# 8   Eastern North America  stable shallow crust  hybrid empirical    NaN
# 9        Peninsular India  stable shallow crust        simulation    NaN
# 10  Eastern North America  stable shallow crust         simulated    NaN
# 11                  Japan            subduction               111   8150
# 12                 global  subduction interface                80   1155
# 13               Cascadia  subduction interface        simulation    NaN
# 14                 global  subduction intraslab                80   1155
# 15                 global  subduction intraslab                80   1155
# 16    Northeastern Taiwan  subduction intraslab                54   4823
# 17       Indo-Myanmar Arc  subduction intraslab                 3     56
# 18                 global  subduction intraslab               164    480
# 19                  Japan  subduction intraslab               269   1725
#
#     Depth [km]  Unnamed: 8  Magnitudes  Unnamed: 10  Distance [km]  \
# 0          NaN         NaN         5.0          7.6              0
# 1          NaN         NaN         5.0          8.0              0
# 2          NaN         NaN         4.0          8.0              0
# 3            0          30         5.5          8.2            NaN
# 4          NaN         NaN         5.0          7.0            NaN
# 5            0          25         4.8          7.6             10
# 6           25          40         4.8          8.1             10
# 7            2          30         5.0          8.3            NaN
# 8          NaN         NaN         5.0          8.2              0
# 9            5          15         4.0          8.0            NaN
# 10         NaN         NaN         5.0          8.0            NaN
# 11          30         200         5.5          8.2            NaN
# 12          20          50         5.0          8.3             10
# 13         NaN         NaN         7.5          9.0            NaN
# 14          50         100         5.0          8.3             30
# 15          50         100         5.0          8.3             30
# 16          39         161         4.1          6.7             40
# 17          91         148         6.3          7.2            NaN
# 18          50         229         5.0          7.8             10
# 19          50         120         5.0          8.3            NaN
#
#     Unnamed: 12
# 0           100
# 1           200
# 2           200
# 3           450
# 4           100
# 5           100
# 6           100
# 7          1000
# 8          1000
# 9           300
# 10         1000
# 11          450
# 12          550
# 13          400
# 14          550
# 15          550
# 16          600
# 17          375
# 18          500
# 19          300

# %%
df_gmpes.to_latex(gmpe_summary_csv.replace('.csv','.tex'), index=False, na_rep='')
